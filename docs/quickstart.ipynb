# %% [markdown]
# # Quickstart #

# %%
import wsynphot
# Out:
# /Users/wkerzend/anaconda3/envs/starkit/lib/python2.7/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-ff7e0c62cbc8> in <module>()
# ----> 1 import wsynphot
#
# /Users/wkerzend/python/wsynphot/wsynphot/__init__.py in <module>()
#      16     # For egg_info test builds to pass, put package imports here.
#      17     if not _ASTROPY_SETUP_:
# ---> 18         from wsynphot.base import (BaseFilterCurve, FilterCurve, FilterSet,
#      19                                    MagnitudeSet)
#      20         from wsynphot.calibration import get_vega
#
# /Users/wkerzend/python/wsynphot/wsynphot/base.py in <module>()
# ...

# %% [markdown]
# Listing available filters

# %%
filter = wsynphot.FilterCurve.load_filter('Keck/NIRC2/Kp')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-67f9bcefb4c8> in <module>()
# ----> 1 filter = wsynphot.FilterCurve.load_filter('Keck/NIRC2/Kp')
#
# /Users/wkerzend/python/wsynphot/wsynphot/base.pyc in load_filter(cls, filter_name, interpolation_kind)
#      99             raise IOError('Filter Data does not exist at - {0} - please '
#     100                           'download it by doing wsynphot.download_filter_data'
# --> 101                           '()'.format(FILTER_DATA_PATH))
#     102         if filter_name is None:
#     103             filter_index = pd.read_hdf(FILTER_DATA_PATH, 'index')
#
# IOError: Filter Data does not exist at - /Users/wkerzend/python/wsynphot/wsynphot/data/filter_data.h5 - please download it by doing wsynphot.download_filter_data()

# %%
wsynphot.delete_all()
# Out:
# Filter Data does not exist - nothing to delete
# Filter Data does not exist - nothing to delete

# %%
wsynphot.download_all()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-34e4438bb424> in <module>()
# ----> 1 wsynphot.download_all()
#
# /Users/wkerzend/python/wsynphot/wsynphot/data/base.py in download_all()
#     105 def download_all():
#     106     download_filter_data()
# --> 107     download_calibration_data()
#     108
#     109 def delete_all():
#
# /Users/wkerzend/python/wsynphot/wsynphot/data/base.py in download_calibration_data()
#      95         print('Alpha Lyra calibration already exists - not downloading')
#      96
# ---> 97     download_from_url(ALPHA_LYR_MOD_URL, ALPHA_LYR_PATH)
#      98
#      99 def delete_calibration_data():
#
# /Users/wkerzend/python/wsynphot/wsynphot/data/base.py in download_from_url(url, filename)
#      75                   desc=os.path.basename(filename)) as t:  # all optional kwargs
# ...

# %%
wsynphot.FilterCurve.load_filter()
# Out:
#               Filter ID  lambda_mean  lambda_eff  lambda_min  lambda_max  \
# 0         2MASS/2MASS.J      12350.0     12350.0       10806       14068
# 1         2MASS/2MASS.H      16620.0     16620.0       14787       18231
# 2        2MASS/2MASS.Ks      21590.0     21590.0       19544       23552
# 3         AAO/AAO.aao21       3580.6      3634.3        3014        4172
# 4         AAO/AAO.aao48       3638.4      3692.7        3113        4168
# 5         AAO/AAO.aao70       3758.9      3770.8        3643        3871
# 6         AAO/AAO.aao71       3904.0      3905.9        3786        4026
# 7         AAO/AAO.aao72       4123.8      4125.3        3989        4273
# 8         AAO/AAO.aao49       4279.5      4267.8        3533        5234
# 9          AAO/AAO.aao1       4384.2      4351.7        3539        5764
# 10        AAO/AAO.aao44       4407.8      4369.7        3655        5300
# 11        AAO/AAO.aao22       4433.6      4391.7        3612        5300
# ...

# %%
filter = wsynphot.FilterCurve.load_filter('Keck/NIRC2/Kp')

# %%
# %pylab notebook

plot(filter.wavelength, filter.transmission_lambda)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/wkerzend/anaconda3/envs/starkit/lib/python2.7/site-packages/matplotlib/__init__.py:1035: UserWarning: Duplicate key in file "/Users/wkerzend/.matplotlib/stylelib/talk_default.mplstyle", line #33
#   (fname, cnt))
# /Users/wkerzend/anaconda3/envs/starkit/lib/python2.7/site-packages/matplotlib/__init__.py:1035: UserWarning: Duplicate key in file "/Users/wkerzend/.matplotlib/stylelib/talk_default.mplstyle", line #39
#   (fname, cnt))
# /Users/wkerzend/anaconda3/envs/starkit/lib/python2.7/site-packages/matplotlib/__init__.py:1035: UserWarning: Duplicate key in file "/Users/wkerzend/.matplotlib/stylelib/talk_default.mplstyle", line #40
#   (fname, cnt))
# <img src="data:image/png;base64,...">

# %%
filter.zp_vega_f_lambda
# Out:
# <Quantity 4.582049863552183e-11 erg / (Angstrom cm2 s)>
