# %% [markdown]
# # Quickstart #

# %%
import wsynphot
# Out:
# [py.warnings         ][WARNING]  /home/jpolygon/miniconda3/envs/sktest2/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)
#  (warnings.py:99)

# %% [markdown]
# ## Getting filter data ready to use

# %% [markdown]
# If you are using wsynphot for *1st time*, **YOU NEED TO DOWNLOAD THE FILTER DATA** by using:

# %%
# wsynphot.download_filter_data()

# %% [markdown]
# This will *cache the filter data on your disk* so that everytime you call any wsynphot function like `list_filters()` that requires data, the data will be accessed from cache.

# %% [markdown]
# Wsynphot will even remind you to **update your cached filter data**, when it becomes more than a month since the last update. If you want to update it at the moment, use:

# %%
# wsynphot.update_filter_data()

# %% [markdown]
# ## Listing available filters

# %% [markdown]
# The filter index (all available filters with their properties) can be listed as:

# %%
wsynphot.list_filters()
# Out:
# [py.warnings         ][WARNING]  /home/jpolygon/miniconda3/envs/sktest2/lib/python3.6/site-packages/astropy/io/votable/tree.py:283: W06: /home/jpolygon/Downloads/wsynphot/filters/SVO/index.vot:15:3: W06: Invalid UCD 'instr.obsty': Secondary word 'instr.obsty' is not valid as a primary word
#   vo_warn(W06, (ucd, six.text_type(e)), config, pos)
#  (warnings.py:99)
# [WARNING] [py.warnings         ] /home/jpolygon/miniconda3/envs/sktest2/lib/python3.6/site-packages/astropy/io/votable/tree.py:283: W06: /home/jpolygon/Downloads/wsynphot/filters/SVO/index.vot:15:3: W06: Invalid UCD 'instr.obsty': Secondary word 'instr.obsty' is not valid as a primary word
#   vo_warn(W06, (ucd, six.text_type(e)), config, pos)
#  (warnings.py:99)
# [py.warnings         ][WARNING]  /home/jpolygon/miniconda3/envs/sktest2/lib/python3.6/site-packages/astropy/io/votable/tree.py:283: W06: /home/jpolygon/Downloads/wsynphot/filters/SVO/index.vot:37:3: W06: Invalid UCD 'DATA_LINK': Unknown word 'DATA_LINK'
#   vo_warn(W06, (ucd, six.text_type(e)), config, pos)
#  (warnings.py:99)
# [WARNING] [py.warnings         ] /home/jpolygon/miniconda3/envs/sktest2/lib/python3.6/site-packages/astropy/io/votable/tree.py:283: W06: /home/jpolygon/Downloads/wsynphot/filters/SVO/index.vot:37:3: W06: Invalid UCD 'DATA_LINK': Unknown word 'DATA_LINK'
#   vo_warn(W06, (ucd, six.text_type(e)), config, pos)
#  (warnings.py:99)
#      FilterProfileService                    filterID WavelengthUnit  \
# 0           ivo://svo/fps         HST/STIS_FUV.F25LYA       Angstrom
# 1           ivo://svo/fps   HST/STIS_FUV.F25LYA_G140L       Angstrom
# 2           ivo://svo/fps   HST/STIS_FUV.F25LYA_G140M       Angstrom
# 3           ivo://svo/fps           IUE/IUE.1250-1300       Angstrom
# 4           ivo://svo/fps           HST/ACS_SBC.F122M       Angstrom
# 5           ivo://svo/fps              TD1/SPEC.F1360       Angstrom
# 6           ivo://svo/fps   HST/STIS_FUV.25MAMA_G140M       Angstrom
# 7           ivo://svo/fps   HST/STIS_FUV.F25ND3_G140M       Angstrom
# 8           ivo://svo/fps   HST/STIS_FUV.25MAMA_G140L       Angstrom
# 9           ivo://svo/fps   HST/STIS_FUV.F25ND3_G140L       Angstrom
# 10          ivo://svo/fps   HST/STIS_FUV.F25ND5_G140M       Angstrom
# 11          ivo://svo/fps              TD1/SPEC.F1380       Angstrom
# 12          ivo://svo/fps   HST/STIS_FUV.F25ND5_G140L       Angstrom
# 13          ivo://svo/fps  HST/STIS_FUV.F25NDQ2_G140M       Angstrom
# 14          ivo://svo/fps         HST/STIS_FUV.25MAMA       Angstrom
# 15          ivo://svo/fps         HST/STIS_FUV.F25ND3       Angstrom
# 16          ivo://svo/fps  HST/STIS_FUV.F25NDQ3_G140M       Angstrom
# 17          ivo://svo/fps  HST/STIS_FUV.F25NDQ2_G140L       Angstrom
# 18          ivo://svo/fps  HST/STIS_FUV.F25NDQ3_G140L       Angstrom
# 19          ivo://svo/fps                 TD1/TD1.140       Angstrom
# 20          ivo://svo/fps            TD1/NARROW1.1400       Angstrom
# 21          ivo://svo/fps              TD1/SPEC.F1400       Angstrom
# 22          ivo://svo/fps  HST/STIS_FUV.F25NDQ1_G140M       Angstrom
# 23          ivo://svo/fps  HST/STIS_FUV.F25NDQ1_G140L       Angstrom
# 24          ivo://svo/fps         HST/STIS_FUV.F25ND5       Angstrom
# 25          ivo://svo/fps  HST/STIS_FUV.F25NDQ4_G140M       Angstrom
# 26          ivo://svo/fps  HST/STIS_FUV.F25NDQ4_G140L       Angstrom
# 27          ivo://svo/fps              TD1/SPEC.F1420       Angstrom
# 28          ivo://svo/fps        HST/STIS_FUV.F25NDQ2       Angstrom
# 29          ivo://svo/fps        HST/STIS_FUV.F25NDQ3       Angstrom
# ...                   ...                         ...            ...
# 4990        ivo://svo/fps           Spitzer/MIPS.70mu       Angstrom
# 4991        ivo://svo/fps              ISO/PHT-C.70mu       Angstrom
# 4992        ivo://svo/fps            AKARI/FIS.WIDE-S       Angstrom
# 4993        ivo://svo/fps                SOFIA/HAWC.C       Angstrom
# 4994        ivo://svo/fps              ISO/PHT-C.90mu       Angstrom
# 4995        ivo://svo/fps             COBE/DIRBE.100m       Angstrom
# 4996        ivo://svo/fps             IRAS/IRAS.100mu       Angstrom
# 4997        ivo://svo/fps             ISO/PHT-P.100mu       Angstrom
# 4998        ivo://svo/fps             ISO/PHT-C.100mu       Angstrom
# 4999        ivo://svo/fps         Herschel/Pacs.green       Angstrom
# 5000        ivo://svo/fps             ISO/PHT-C.105mu       Angstrom
# 5001        ivo://svo/fps             ISO/PHT-C.120mu       Angstrom
# 5002        ivo://svo/fps            AKARI/FIS.WIDE-L       Angstrom
# 5003        ivo://svo/fps             COBE/DIRBE.140m       Angstrom
# 5004        ivo://svo/fps             ISO/PHT-C.135mu       Angstrom
# 5005        ivo://svo/fps                SOFIA/HAWC.D       Angstrom
# 5006        ivo://svo/fps          Spitzer/MIPS.160mu       Angstrom
# 5007        ivo://svo/fps              AKARI/FIS.N160       Angstrom
# 5008        ivo://svo/fps           Herschel/Pacs.red       Angstrom
# 5009        ivo://svo/fps             ISO/PHT-C.160mu       Angstrom
# 5010        ivo://svo/fps             ISO/PHT-C.180mu       Angstrom
# 5011        ivo://svo/fps             ISO/PHT-C.200mu       Angstrom
# 5012        ivo://svo/fps                SOFIA/HAWC.E       Angstrom
# 5013        ivo://svo/fps          Herschel/SPIRE.PSW       Angstrom
# 5014        ivo://svo/fps             COBE/DIRBE.240m       Angstrom
# 5015        ivo://svo/fps      Herschel/SPIRE.PSW_ext       Angstrom
# 5016        ivo://svo/fps          Herschel/SPIRE.PMW       Angstrom
# 5017        ivo://svo/fps      Herschel/SPIRE.PMW_ext       Angstrom
# 5018        ivo://svo/fps          Herschel/SPIRE.PLW       Angstrom
# 5019        ivo://svo/fps      Herschel/SPIRE.PLW_ext       Angstrom
#
#      WavelengthUCD PhotSystem DetectorType Band Instrument  Facility  \
# 0            em.wl                       1            STIS       HST
# 1            em.wl                       1            STIS       HST
# 2            em.wl                       1            STIS       HST
# 3            em.wl        IUE            0                       IUE
# 4            em.wl                       1             ACS       HST
# 5            em.wl        TD1            0             TD1       TD1
# 6            em.wl                       1            STIS       HST
# 7            em.wl                       1            STIS       HST
# 8            em.wl                       1            STIS       HST
# 9            em.wl                       1            STIS       HST
# 10           em.wl                       1            STIS       HST
# 11           em.wl        TD1            0             TD1       TD1
# 12           em.wl                       1            STIS       HST
# 13           em.wl                       1            STIS       HST
# 14           em.wl                       1            STIS       HST
# 15           em.wl                       1            STIS       HST
# 16           em.wl                       1            STIS       HST
# 17           em.wl                       1            STIS       HST
# 18           em.wl                       1            STIS       HST
# 19           em.wl        TD1            0             TD1       TD1
# 20           em.wl        TD1            0             TD1       TD1
# 21           em.wl        TD1            0             TD1       TD1
# 22           em.wl                       1            STIS       HST
# 23           em.wl                       1            STIS       HST
# 24           em.wl                       1            STIS       HST
# 25           em.wl                       1            STIS       HST
# 26           em.wl                       1            STIS       HST
# 27           em.wl        TD1            0             TD1       TD1
# 28           em.wl                       1            STIS       HST
# 29           em.wl                       1            STIS       HST
# ...            ...        ...          ...  ...        ...       ...
# 4990         em.wl       MIPS            0            MIPS   Spitzer
# 4991         em.wl        ISO            0             PHT       ISO
# 4992         em.wl        FIS            0             FIS     AKARI
# 4993         em.wl                       0            HAWC     SOFIA
# 4994         em.wl        ISO            0             PHT       ISO
# 4995         em.wl      DIRBE            0           DIRBE      COBE
# 4996         em.wl       IRAS            0                      IRAS
# 4997         em.wl        ISO            0             PHT       ISO
# 4998         em.wl        ISO            0             PHT       ISO
# 4999         em.wl   Herschel            0            Pacs  Herschel
# 5000         em.wl        ISO            0             PHT       ISO
# 5001         em.wl        ISO            0             PHT       ISO
# 5002         em.wl        FIS            0             FIS     AKARI
# 5003         em.wl      DIRBE            0           DIRBE      COBE
# 5004         em.wl        ISO            0             PHT       ISO
# 5005         em.wl                       0            HAWC     SOFIA
# 5006         em.wl       MIPS            0            MIPS   Spitzer
# 5007         em.wl        FIS            0             FIS     AKARI
# 5008         em.wl   Herschel            0            Pacs  Herschel
# 5009         em.wl        ISO            0             PHT       ISO
# 5010         em.wl        ISO            0             PHT       ISO
# 5011         em.wl        ISO            0             PHT       ISO
# 5012         em.wl                       0            HAWC     SOFIA
# 5013         em.wl      SPIRE            0           SPIRE  Herschel
# 5014         em.wl      DIRBE            0           DIRBE      COBE
# 5015         em.wl      SPIRE            0           SPIRE  Herschel
# 5016         em.wl      SPIRE            0           SPIRE  Herschel
# 5017         em.wl      SPIRE            0           SPIRE  Herschel
# 5018         em.wl      SPIRE            0           SPIRE  Herschel
# 5019         em.wl      SPIRE            0           SPIRE  Herschel
#
#                                        ProfileReference  ... WavelengthPhot  \
# 0     https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.376536e+03
# 1     https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.364339e+03
# 2     https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.361286e+03
# 3                                                        ...   1.284802e+03
# 4     https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.432717e+03
# 5     http://adsabs.harvard.edu/abs/1976A%26A....49....  ...   1.360629e+03
# 6     https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.451699e+03
# 7     https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.449844e+03
# 8     https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.454146e+03
# 9     https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.452543e+03
# 10    https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.461439e+03
# 11    http://adsabs.harvard.edu/abs/1976A%26A....49....  ...   1.380699e+03
# 12    https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.463900e+03
# 13    https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.467325e+03
# 14    https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.489032e+03
# 15    https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.483534e+03
# 16    https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.469030e+03
# 17    https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.469412e+03
# 18    https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.471105e+03
# 19                                                       ...   1.403559e+03
# 20    http://ulisse.pd.astro.it/Astro/ADPS/ADPS2/Fil...  ...   1.403563e+03
# 21    http://adsabs.harvard.edu/abs/1976A%26A....49....  ...   1.400882e+03
# 22    https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.470560e+03
# 23    https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.472481e+03
# 24    https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.498128e+03
# 25    https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.477624e+03
# 26    https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.479140e+03
# 27    http://adsabs.harvard.edu/abs/1976A%26A....49....  ...   1.420684e+03
# 28    https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.506156e+03
# 29    https://stsynphot.readthedocs.io/en/latest/sts...  ...   1.507273e+03
# ...                                                 ...  ...            ...
# 4990  http://ssc.spitzer.caltech.edu/mips/spectral_r...  ...   6.936470e+05
# 4991  http://general-tools.cosmos.esa.int/iso/manual...  ...   7.455638e+05
# 4992  http://www.ir.isas.jaxa.jp/AKARI/Observation/R...  ...   8.036109e+05
# 4993  https://www.sofia.usra.edu/science/proposing-a...  ...   8.835179e+05
# 4994  http://general-tools.cosmos.esa.int/iso/manual...  ...   8.544859e+05
# 4995  https://lambda.gsfc.nasa.gov/product/cobe/c_sp...  ...   9.412082e+05
# 4996  http://irsa.ipac.caltech.edu/IRASdocs/exp.sup/...  ...   9.694183e+05
# 4997  http://general-tools.cosmos.esa.int/iso/manual...  ...   9.824935e+05
# 4998  http://general-tools.cosmos.esa.int/iso/manual...  ...   9.678518e+05
# 4999  https://nhscsci.ipac.caltech.edu/sc/index.php/...  ...   9.901764e+05
# 5000  http://general-tools.cosmos.esa.int/iso/manual...  ...   1.032345e+06
# 5001  http://general-tools.cosmos.esa.int/iso/manual...  ...   1.124067e+06
# 5002  http://www.ir.isas.jaxa.jp/AKARI/Observation/R...  ...   1.429926e+06
# 5003  https://lambda.gsfc.nasa.gov/product/cobe/c_sp...  ...   1.420013e+06
# 5004  http://general-tools.cosmos.esa.int/iso/manual...  ...   1.453382e+06
# 5005  https://www.sofia.usra.edu/science/proposing-a...  ...   1.536151e+06
# 5006  http://ssc.spitzer.caltech.edu/mips/spectral_r...  ...   1.536888e+06
# 5007  http://www.ir.isas.jaxa.jp/AKARI/Observation/R...  ...   1.603095e+06
# 5008  https://nhscsci.ipac.caltech.edu/sc/index.php/...  ...   1.569063e+06
# 5009  http://general-tools.cosmos.esa.int/iso/manual...  ...   1.597013e+06
# 5010  http://general-tools.cosmos.esa.int/iso/manual...  ...   1.742852e+06
# 5011  http://general-tools.cosmos.esa.int/iso/manual...  ...   1.979992e+06
# 5012  https://www.sofia.usra.edu/science/proposing-a...  ...   2.123903e+06
# 5013  http://herschel.esac.esa.int/Docs/SPIRE/html/s...  ...   2.449650e+06
# 5014  https://lambda.gsfc.nasa.gov/product/cobe/c_sp...  ...   2.353122e+06
# 5015  http://herschel.esac.esa.int/Docs/SPIRE/html/s...  ...   2.492830e+06
# 5016  http://herschel.esac.esa.int/Docs/SPIRE/html/s...  ...   3.437871e+06
# 5017  http://herschel.esac.esa.int/Docs/SPIRE/html/s...  ...   3.496571e+06
# 5018  http://herschel.esac.esa.int/Docs/SPIRE/html/s...  ...   4.890142e+06
# 5019  http://herschel.esac.esa.int/Docs/SPIRE/html/s...  ...   5.034501e+06
#
#               FWHM                        PhotCalID  MagSys   ZeroPoint  \
# 0     8.046415e+01         HST/STIS_FUV.F25LYA/Vega    Vega   59.921341
# 1     9.856856e+01   HST/STIS_FUV.F25LYA_G140L/Vega    Vega   63.976688
# 2     9.450593e+01   HST/STIS_FUV.F25LYA_G140M/Vega    Vega   62.946198
# 3     5.100000e+01           IUE/IUE.1250-1300/Vega    Vega   78.500328
# 4     1.011414e+02           HST/ACS_SBC.F122M/Vega    Vega  119.552032
# 5     3.493550e+01              TD1/SPEC.F1360/Vega    Vega  305.763611
# 6     2.392322e+02   HST/STIS_FUV.25MAMA_G140M/Vega    Vega  263.913055
# 7     2.402186e+02   HST/STIS_FUV.F25ND3_G140M/Vega    Vega  269.066925
# 8     2.577850e+02   HST/STIS_FUV.25MAMA_G140L/Vega    Vega  271.152496
# 9     2.583499e+02   HST/STIS_FUV.F25ND3_G140L/Vega    Vega  276.551300
# 10    2.324531e+02   HST/STIS_FUV.F25ND5_G140M/Vega    Vega  276.351379
# 11    3.493550e+01              TD1/SPEC.F1380/Vega    Vega  333.016724
# 12    2.517317e+02   HST/STIS_FUV.F25ND5_G140L/Vega    Vega  284.244690
# 13    2.803337e+02  HST/STIS_FUV.F25NDQ2_G140M/Vega    Vega  301.360229
# 14    2.873541e+02         HST/STIS_FUV.25MAMA/Vega    Vega  294.259918
# 15    2.949548e+02         HST/STIS_FUV.F25ND3/Vega    Vega  297.713226
# 16    3.032110e+02  HST/STIS_FUV.F25NDQ3_G140M/Vega    Vega  307.499847
# 17    3.071084e+02  HST/STIS_FUV.F25NDQ2_G140L/Vega    Vega  309.404938
# 18    3.276010e+02  HST/STIS_FUV.F25NDQ3_G140L/Vega    Vega  315.557678
# 19    1.000010e+02                 TD1/TD1.140/Vega    Vega  368.054199
# 20    1.000000e+02            TD1/NARROW1.1400/Vega    Vega  368.077026
# 21    3.493550e+01              TD1/SPEC.F1400/Vega    Vega  365.678650
# 22    2.866362e+02  HST/STIS_FUV.F25NDQ1_G140M/Vega    Vega  317.319885
# 23    3.029540e+02  HST/STIS_FUV.F25NDQ1_G140L/Vega    Vega  325.051025
# 24    2.925464e+02         HST/STIS_FUV.F25ND5/Vega    Vega  309.317474
# 25    3.078364e+02  HST/STIS_FUV.F25NDQ4_G140M/Vega    Vega  341.076538
# 26    3.221737e+02  HST/STIS_FUV.F25NDQ4_G140L/Vega    Vega  348.640503
# 27    3.493550e+01              TD1/SPEC.F1420/Vega    Vega  404.690247
# 28    3.592179e+02        HST/STIS_FUV.F25NDQ2/Vega    Vega  337.573486
# 29    3.811847e+02        HST/STIS_FUV.F25NDQ3/Vega    Vega  343.337189
# ...            ...                              ...     ...         ...
# 4990  1.898351e+05           Spitzer/MIPS.70mu/Vega    Vega    0.769955
# 4991  2.163768e+05              ISO/PHT-C.70mu/Vega    Vega    0.636514
# 4992  2.707058e+05            AKARI/FIS.WIDE-S/Vega    Vega    0.515878
# 4993  1.704136e+05                SOFIA/HAWC.C/Vega    Vega    0.490535
# 4994  3.841473e+05              ISO/PHT-C.90mu/Vega    Vega    0.455685
# 4995  3.097860e+05             COBE/DIRBE.100m/Vega    Vega    0.406927
# 4996  3.222499e+05             IRAS/IRAS.100mu/Vega    Vega    0.386524
# 4997  3.004847e+05             ISO/PHT-P.100mu/Vega    Vega    0.380426
# 4998  3.355158e+05             ISO/PHT-C.100mu/Vega    Vega    0.383468
# 4999  3.568660e+05         Herschel/Pacs.green/Vega    Vega    0.378392
# 5000  2.100148e+05             ISO/PHT-C.105mu/Vega    Vega    0.345418
# 5001  2.165200e+05             ISO/PHT-C.120mu/Vega    Vega    0.283105
# 5002  3.894922e+05            AKARI/FIS.WIDE-L/Vega    Vega    0.176714
# 5003  3.514022e+05             COBE/DIRBE.140m/Vega    Vega    0.176088
# 5004  4.405572e+05             ISO/PHT-C.135mu/Vega    Vega    0.167201
# 5005  3.394504e+05                SOFIA/HAWC.D/Vega    Vega    0.158686
# 5006  3.454720e+05          Spitzer/MIPS.160mu/Vega    Vega    0.157904
# 5007  3.327812e+05              AKARI/FIS.N160/Vega    Vega    0.145898
# 5008  7.495406e+05           Herschel/Pacs.red/Vega    Vega    0.143548
# 5009  5.584378e+05             ISO/PHT-C.160mu/Vega    Vega    0.134895
# 5010  4.259885e+05             ISO/PHT-C.180mu/Vega    Vega    0.119502
# 5011  2.962398e+05             ISO/PHT-C.200mu/Vega    Vega    0.094259
# 5012  4.403009e+05                SOFIA/HAWC.E/Vega    Vega    0.082318
# 5013  7.770002e+05          Herschel/SPIRE.PSW/Vega    Vega    0.060750
# 5014  1.008312e+06             COBE/DIRBE.240m/Vega    Vega    0.061681
# 5015  6.589304e+05      Herschel/SPIRE.PSW_ext/Vega    Vega    0.058680
# 5016  1.059688e+06          Herschel/SPIRE.PMW/Vega    Vega    0.030295
# 5017  9.371992e+05      Herschel/SPIRE.PMW_ext/Vega    Vega    0.029263
# 5018  1.998631e+06          Herschel/SPIRE.PLW/Vega    Vega    0.014141
# 5019  1.848042e+06      Herschel/SPIRE.PLW_ext/Vega    Vega    0.013288
#
#       ZeroPointUnit  Mag0  ZeroPointType  AsinhSoft  \
# 0                Jy   0.0                       0.0
# 1                Jy   0.0                       0.0
# 2                Jy   0.0                       0.0
# 3                Jy   0.0         Pogson        0.0
# 4                Jy   0.0                       0.0
# 5                Jy   0.0         Pogson        0.0
# 6                Jy   0.0                       0.0
# 7                Jy   0.0                       0.0
# 8                Jy   0.0                       0.0
# 9                Jy   0.0                       0.0
# 10               Jy   0.0                       0.0
# 11               Jy   0.0         Pogson        0.0
# 12               Jy   0.0                       0.0
# 13               Jy   0.0                       0.0
# 14               Jy   0.0                       0.0
# 15               Jy   0.0                       0.0
# 16               Jy   0.0                       0.0
# 17               Jy   0.0                       0.0
# 18               Jy   0.0                       0.0
# 19               Jy   0.0         Pogson        0.0
# 20               Jy   0.0         Pogson        0.0
# 21               Jy   0.0         Pogson        0.0
# 22               Jy   0.0                       0.0
# 23               Jy   0.0                       0.0
# 24               Jy   0.0                       0.0
# 25               Jy   0.0                       0.0
# 26               Jy   0.0                       0.0
# 27               Jy   0.0         Pogson        0.0
# 28               Jy   0.0                       0.0
# 29               Jy   0.0                       0.0
# ...             ...   ...            ...        ...
# 4990             Jy   0.0         Pogson        0.0
# 4991             Jy   0.0         Pogson        0.0
# 4992             Jy   0.0         Pogson        0.0
# 4993             Jy   0.0         Pogson        0.0
# 4994             Jy   0.0         Pogson        0.0
# 4995             Jy   0.0         Pogson        0.0
# 4996             Jy   0.0         Pogson        0.0
# 4997             Jy   0.0         Pogson        0.0
# 4998             Jy   0.0         Pogson        0.0
# 4999             Jy   0.0         Pogson        0.0
# 5000             Jy   0.0         Pogson        0.0
# 5001             Jy   0.0         Pogson        0.0
# 5002             Jy   0.0         Pogson        0.0
# 5003             Jy   0.0         Pogson        0.0
# 5004             Jy   0.0         Pogson        0.0
# 5005             Jy   0.0         Pogson        0.0
# 5006             Jy   0.0         Pogson        0.0
# 5007             Jy   0.0         Pogson        0.0
# 5008             Jy   0.0         Pogson        0.0
# 5009             Jy   0.0         Pogson        0.0
# 5010             Jy   0.0         Pogson        0.0
# 5011             Jy   0.0         Pogson        0.0
# 5012             Jy   0.0         Pogson        0.0
# 5013             Jy   0.0         Pogson        0.0
# 5014             Jy   0.0         Pogson        0.0
# 5015             Jy   0.0         Pogson        0.0
# 5016             Jy   0.0         Pogson        0.0
# 5017             Jy   0.0         Pogson        0.0
# 5018             Jy   0.0         Pogson        0.0
# 5019             Jy   0.0         Pogson        0.0
#
#                                        TrasmissionCurve
# 0     http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 1     http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 2     http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 3     http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 4     http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 5     http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 6     http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 7     http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 8     http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 9     http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 10    http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 11    http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 12    http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 13    http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 14    http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 15    http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 16    http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 17    http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 18    http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 19    http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 20    http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 21    http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 22    http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 23    http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 24    http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 25    http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 26    http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 27    http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 28    http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 29    http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# ...                                                 ...
# 4990  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 4991  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 4992  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 4993  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 4994  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 4995  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 4996  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 4997  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 4998  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 4999  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 5000  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 5001  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 5002  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 5003  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 5004  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 5005  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 5006  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 5007  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 5008  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 5009  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 5010  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 5011  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 5012  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 5013  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 5014  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 5015  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 5016  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 5017  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 5018  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
# 5019  http://svo2.cab.inta-csic.es//theory/fps/fps.p...
#
# [5020 rows x 31 columns]

# %% [markdown]
# ## Filter Curve

# %% [markdown]
# Create a filter curve object:

# %%
filter = wsynphot.FilterCurve.load_filter('Keck/NIRC2/Kp')
filter
# Out:
# FilterCurve <Keck/NIRC2/Kp>

# %% [markdown]
# Plot the curve by plot() method:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (9,6)

filter.plot(plt.gca())

# %% [markdown]
# Do any required calculations on the filter curve object:

# %%
filter.zp_vega_f_lambda
# Out:
# <Quantity 4.602862782749426e-11 erg / (Angstrom cm2 s)>

# %%
filter.convert_vega_magnitude_to_f_lambda(0)
# Out:
# <Quantity 4.602862782749426e-11 erg / (Angstrom cm2 s)>

# %%
filter.convert_vega_magnitude_to_f_lambda(14.5)
# Out:
# <Quantity 7.29504589021217e-17 erg / (Angstrom cm2 s)>
