# %% [markdown]
# # Quickstart #

# %%
import wsynphot
# Out:
# [py.warnings         ][WARNING]  /Users/wkerzend/miniconda/envs/starkit/lib/python2.7/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)
#  (__init__.py:14)

# %% [markdown]
# Listing available filters

# %%
wsynphot.list_filters()
# Out:
#                             Filter ID  lambda_mean  lambda_eff  lambda_min  \
# wsynphot_filter_id
# 2MASS/2MASS/J           2MASS/2MASS.J      12350.0     12350.0       10806
# 2MASS/2MASS/H           2MASS/2MASS.H      16620.0     16620.0       14787
# 2MASS/2MASS/Ks         2MASS/2MASS.Ks      21590.0     21590.0       19544
# AAO/AAO/aao21           AAO/AAO.aao21       3580.6      3634.3        3014
# AAO/AAO/aao48           AAO/AAO.aao48       3638.4      3692.7        3113
# AAO/AAO/aao70           AAO/AAO.aao70       3758.9      3770.8        3643
# AAO/AAO/aao71           AAO/AAO.aao71       3904.0      3905.9        3786
# AAO/AAO/aao72           AAO/AAO.aao72       4123.8      4125.3        3989
# AAO/AAO/aao49           AAO/AAO.aao49       4279.5      4267.8        3533
# AAO/AAO/aao1             AAO/AAO.aao1       4384.2      4351.7        3539
# AAO/AAO/aao44           AAO/AAO.aao44       4407.8      4369.7        3655
# AAO/AAO/aao22           AAO/AAO.aao22       4433.6      4391.7        3612
# AAO/AAO/aao5             AAO/AAO.aao5       4483.1      4430.2        3591
# AAO/AAO/aao53           AAO/AAO.aao53       4693.0      4692.9        4666
# AAO/AAO/aao90           AAO/AAO.aao90       4764.8      4665.0        3838
# AAO/AAO/aao60           AAO/AAO.aao60       4886.1      4888.8        4787
# AAO/AAO/aao8             AAO/AAO.aao8       4956.9      4800.0        3589
# AAO/AAO/aao73           AAO/AAO.aao73       5003.8      5005.2        4805
# AAO/AAO/aao63           AAO/AAO.aao63       5016.1      5013.3        4701
# AAO/AAO/aao54           AAO/AAO.aao54       5022.6      5022.5        4970
# AAO/AAO/aao62           AAO/AAO.aao62       5234.8      5224.5        4927
# AAO/AAO/aao2             AAO/AAO.aao2       5401.6      5349.4        4707
# AAO/AAO/aao50           AAO/AAO.aao50       5449.4      5386.7        4721
# AAO/AAO/aao45           AAO/AAO.aao45       5449.6      5397.0        4850
# AAO/AAO/aao23           AAO/AAO.aao23       5475.6      5416.2        4725
# AAO/AAO/aao74           AAO/AAO.aao74       5818.6      5816.7        5681
# AAO/AAO/aao55           AAO/AAO.aao55       5898.9      5898.8        5854
# AAO/AAO/aao91           AAO/AAO.aao91       6293.1      6209.0        5432
# AAO/AAO/aao56           AAO/AAO.aao56       6309.1      6309.0        6267
# AAO/AAO/aao46           AAO/AAO.aao46       6493.4      6358.4        5552
# ...                               ...          ...         ...         ...
# WHT/PFIP/Har_B         WHT/PFIP.Har_B       4337.9      4316.6        3522
# WHT/PFIP/Har_V         WHT/PFIP.Har_V       5489.9      5425.4        4836
# WHT/PFIP/Har_R         WHT/PFIP.Har_R       6596.7      6402.5        5478
# WHT/PFIP/Har_I         WHT/PFIP.Har_I       8136.1      8047.9        7060
# WISE/WISE/W1             WISE/WISE.W1      33526.0     33526.0       27541
# WISE/WISE/W2             WISE/WISE.W2      46028.0     46028.0       39633
# WISE/WISE/W3             WISE/WISE.W3     115608.0    115608.0       74430
# WISE/WISE/W4             WISE/WISE.W4     220883.0    220883.0      195201
# WIYN/ODI/u                 WIYN/ODI.u       3585.0      3619.5        3237
# WIYN/ODI/NB422         WIYN/ODI.NB422       4224.1      4221.8        4096
# WIYN/ODI/g                 WIYN/ODI.g       4806.0      4702.1        3797
# WIYN/ODI/r                 WIYN/ODI.r       6219.3      6136.3        5423
# WIYN/ODI/NB695         WIYN/ODI.NB695       6954.9      6954.5        6874
# WIYN/ODI/i                 WIYN/ODI.i       7567.6      7508.2        6790
# WIYN/ODI/z                 WIYN/ODI.z       8689.2      8667.8        8008
# WIYN/WHIRC/LO           WIYN/WHIRC.LO      10595.5     10594.9       10477
# WIYN/WHIRC/He           WIYN/WHIRC.He      10818.8     10818.4       10731
# WIYN/WHIRC/CN           WIYN/WHIRC.CN      11074.2     11074.0       10944
# WIYN/WHIRC/J_MKO     WIYN/WHIRC.J_MKO      12506.2     12440.0       11514
# WIYN/WHIRC/Pab         WIYN/WHIRC.Pab      12828.8     12828.4       12668
# WIYN/WHIRC/Pab45     WIYN/WHIRC.Pab45      13028.0     13027.5       12883
# WIYN/WHIRC/Fe           WIYN/WHIRC.Fe      16490.2     16491.8       16333
# WIYN/WHIRC/H_MKO     WIYN/WHIRC.H_MKO      16651.1     16499.4       14811
# WIYN/WHIRC/Fe45       WIYN/WHIRC.Fe45      16689.3     16687.6       16542
# WIYN/WHIRC/H2           WIYN/WHIRC.H2      21205.0     21204.1       21000
# WIYN/WHIRC/Brg         WIYN/WHIRC.Brg      21659.5     21658.6       21457
# WIYN/WHIRC/Ks_MKO   WIYN/WHIRC.Ks_MKO      21776.9     21607.0       19626
# WIYN/WHIRC/Brg45     WIYN/WHIRC.Brg45      21888.6     21887.9       21645
# WIYN/WHIRC/CO_n       WIYN/WHIRC.CO-n      22962.2     22961.3       22748
# WIYN/WHIRC/CO_w       WIYN/WHIRC.CO-w      23432.7     23418.0       22754
#
#                     lambda_max     Weff  ZP (Jy) Obs. Facility Instrument  \
# wsynphot_filter_id
# 2MASS/2MASS/J            14068   1624.1   1594.0         2MASS         NA
# 2MASS/2MASS/H            18231   2509.4   1024.0         2MASS         NA
# 2MASS/2MASS/Ks           23552   2618.9    666.8         2MASS         NA
# AAO/AAO/aao21             4172    642.6   1717.2           AAO         NA
# AAO/AAO/aao48             4168    546.0   1844.3           AAO         NA
# AAO/AAO/aao70             3871    164.1   2007.2           AAO         NA
# AAO/AAO/aao71             4026    167.9   3381.7           AAO         NA
# AAO/AAO/aao72             4273    140.6   4085.3           AAO         NA
# AAO/AAO/aao49             5234    963.0   3869.6           AAO         NA
# AAO/AAO/aao1              5764   1035.6   3926.3           AAO         NA
# AAO/AAO/aao44             5300    959.1   4018.2           AAO         NA
# AAO/AAO/aao22             5300   1067.9   3967.5           AAO         NA
# AAO/AAO/aao5              5811   1100.9   3942.0           AAO         NA
# AAO/AAO/aao53             4722     27.2   4214.0           AAO         NA
# AAO/AAO/aao90             5579   1418.6   3933.9           AAO         NA
# AAO/AAO/aao60             4982    103.8   3442.3           AAO         NA
# AAO/AAO/aao8              6523   1679.0   3756.2           AAO         NA
# AAO/AAO/aao73             5205    306.8   3783.6           AAO         NA
# AAO/AAO/aao63             5330    379.4   3768.4           AAO         NA
# AAO/AAO/aao54             5074     47.0   3942.0           AAO         NA
# AAO/AAO/aao62             5574    377.9   3774.2           AAO         NA
# AAO/AAO/aao2              6496    909.8   3636.9           AAO         NA
# AAO/AAO/aao50             6609    961.2   3609.0           AAO         NA
# AAO/AAO/aao45             6528    890.1   3625.8           AAO         NA
# AAO/AAO/aao23             6381   1044.1   3592.2           AAO         NA
# AAO/AAO/aao74             5969    192.7   3407.4           AAO         NA
# AAO/AAO/aao55             5942     44.0   3353.0           AAO         NA
# AAO/AAO/aao91             7077   1325.9   3112.1           AAO         NA
# AAO/AAO/aao56             6350     42.0   3137.0           AAO         NA
# AAO/AAO/aao46             8300   1360.6   3017.0           AAO         NA
# ...                        ...      ...      ...           ...        ...
# WHT/PFIP/Har_B            5728   1065.5   3856.9           WHT       PFIP
# WHT/PFIP/Har_V            6647    983.9   3599.2           WHT       PFIP
# WHT/PFIP/Har_R            9000   1628.2   2971.8           WHT       PFIP
# WHT/PFIP/Har_I            9000   1644.7   2393.6           WHT       PFIP
# WISE/WISE/W1             38724   6626.4    309.5          WISE         NA
# WISE/WISE/W2             53414  10422.7    171.8          WISE         NA
# WISE/WISE/W3            172613  55055.7     31.7          WISE         NA
# WISE/WISE/W4            279107  41016.8      8.4          WISE         NA
# WIYN/ODI/u                3920    584.2   1623.1          WIYN        ODI
# WIYN/ODI/NB422            4361    170.4   4499.4          WIYN        ODI
# WIYN/ODI/g                5634   1445.3   3929.1          WIYN        ODI
# WIYN/ODI/r                7016   1375.0   3150.4          WIYN        ODI
# WIYN/ODI/NB695            7039     92.8   2830.5          WIYN        ODI
# WIYN/ODI/i                8340   1283.1   2575.6          WIYN        ODI
# WIYN/ODI/z                9353   1038.2   2278.7          WIYN        ODI
# WIYN/WHIRC/LO            10718    131.4   2010.4          WIYN      WHIRC
# WIYN/WHIRC/He            10907     94.7   1937.2          WIYN      WHIRC
# WIYN/WHIRC/CN            11201    165.6   1870.0          WIYN      WHIRC
# WIYN/WHIRC/J_MKO         13505   1597.9   1558.7          WIYN      WHIRC
# WIYN/WHIRC/Pab           13001    163.9   1397.1          WIYN      WHIRC
# WIYN/WHIRC/Pab45         13170    138.3   1473.4          WIYN      WHIRC
# WIYN/WHIRC/Fe            16642    159.5   1019.9          WIYN      WHIRC
# WIYN/WHIRC/H_MKO         18513   2820.7   1013.3          WIYN      WHIRC
# WIYN/WHIRC/Fe45          16834    164.0   1026.5          WIYN      WHIRC
# WIYN/WHIRC/H2            21405    212.3    691.4          WIYN      WHIRC
# WIYN/WHIRC/Brg           21858    210.3    628.8          WIYN      WHIRC
# WIYN/WHIRC/Ks_MKO        24008   3280.3    659.7          WIYN      WHIRC
# WIYN/WHIRC/Brg45         22128    245.2    651.6          WIYN      WHIRC
# WIYN/WHIRC/CO_n          23169    224.9    602.0          WIYN      WHIRC
# WIYN/WHIRC/CO_w          24107   1019.7    581.4          WIYN      WHIRC
#
#                                          Description
# wsynphot_filter_id
# 2MASS/2MASS/J                                2MASS J
# 2MASS/2MASS/H                                2MASS H
# 2MASS/2MASS/Ks                              2MASS Ks
# AAO/AAO/aao21                  AAO #21, aao cus04, U
# AAO/AAO/aao48                       AAO #48, u 48, U
# AAO/AAO/aao70                AAO #70, ttf 375.19, B0
# AAO/AAO/aao71                AAO #71, ttf 390.17, B1
# AAO/AAO/aao72                AAO #72, ttf 411.15, B2
# AAO/AAO/aao49                       AAO #49, b 49, B
# AAO/AAO/aao1                  AAO #1, aao glass b, B
# AAO/AAO/aao44                   AAO #44, anu 75 b, B
# AAO/AAO/aao22                     AAO #22, kpno b, B
# AAO/AAO/aao5                AAO #5, aao glass bj, BJ
# AAO/AAO/aao53           AAO #53, taurus 469.2, He II
# AAO/AAO/aao90                        AAO #90, g t, g
# AAO/AAO/aao60                      AAO #60, wht f101
# AAO/AAO/aao8                AAO #8, aao glass bs, B*
# AAO/AAO/aao73                AAO #73, ttf 500.32, B4
# AAO/AAO/aao63                      AAO #63, wht f107
# AAO/AAO/aao54         AAO #54, taurus 502.3, [O III]
# AAO/AAO/aao62                      AAO #62, wht f126
# AAO/AAO/aao2                  AAO #2, aao glass v, V
# AAO/AAO/aao50                       AAO #50, v 50, V
# AAO/AAO/aao45                   AAO #45, anu 75 v, V
# AAO/AAO/aao23                     AAO #23, kpno v, V
# AAO/AAO/aao74                AAO #74, ttf 582.19, B6
# AAO/AAO/aao55       AAO #55, taurus 590.4, He I/Na D
# AAO/AAO/aao91                        AAO #91, r t, r
# AAO/AAO/aao56           AAO #56, taurus 631.4, [O I]
# AAO/AAO/aao46                   AAO #46, anu 75 r, R
# ...                                              ...
# WHT/PFIP/Har_B                            Harris B 5
# WHT/PFIP/Har_V                            Harris V 5
# WHT/PFIP/Har_R                            Harris R 5
# WHT/PFIP/Har_I                            Harris I 5
# WISE/WISE/W1                          WISE W1 filter
# WISE/WISE/W2                          WISE W2 filter
# WISE/WISE/W3                          WISE W3 filter
# WISE/WISE/W4                          WISE W4 filter
# WIYN/ODI/u                        ODI SDSS u' filter
# WIYN/ODI/NB422                                     Â
# WIYN/ODI/g                        ODI SDSS g' filter
# WIYN/ODI/r                        ODI SDSS r' filter
# WIYN/ODI/NB695                      ODI NB695 filter
# WIYN/ODI/i                        ODI SDSS i' filter
# WIYN/ODI/z                        ODI SDSS z' filter
# WIYN/WHIRC/LO               WHIRC Low airglow filter
# WIYN/WHIRC/He                      WHIRC He I filter
# WIYN/WHIRC/CN                        WHIRC CN filter
# WIYN/WHIRC/J_MKO                  WHIRC J MKO filter
# WIYN/WHIRC/Pab                  WHIRC Pa beta filter
# WIYN/WHIRC/Pab45             WHIRC Pa beta 45 filter
# WIYN/WHIRC/Fe                    WHIRC [FeII] filter
# WIYN/WHIRC/H_MKO                  WHIRC H MKO filter
# WIYN/WHIRC/Fe45               WHIRC [FeII] 45 filter
# WIYN/WHIRC/H2                   WHIRC H2 S(1) filter
# WIYN/WHIRC/Brg                      WHIRC Brg filter
# WIYN/WHIRC/Ks_MKO                WHIRC Ks MKO filter
# WIYN/WHIRC/Brg45                  WHIRC Brg45 filter
# WIYN/WHIRC/CO_n                    WHIRC CO-n filter
# WIYN/WHIRC/CO_w                    WHIRC CO-w filter
#
# [4409 rows x 10 columns]

# %%
wsynphot.FilterCurve.load_filter()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-0162a4b6ef0f> in <module>()
# ----> 1 wsynphot.FilterCurve.load_filter()
#
# /Users/wkerzend/python/wsynphot/wsynphot/base.pyc in load_filter(cls, filter_name, interpolation_kind)
#      96             raise IOError('Filter Data does not exist at - {0} - please '
#      97                           'download it by doing wsynphot.download_filter_data'
# ---> 98                           '()'.format(FILTER_DATA_PATH))
#      99         if filter_name is None:
#     100             filter_index = pd.read_hdf(FILTER_DATA_PATH, 'index')
#
# IOError: Filter Data does not exist at - /Users/wkerzend/python/wsynphot/wsynphot/data/filter_data.h5 - please download it by doing wsynphot.download_filter_data()

# %%
wsynphot.download_filter_data()
# Out:
# SEJveChjaGlsZHJlbj0oSW50UHJvZ3Jlc3ModmFsdWU9MCwgZGVzY3JpcHRpb249dSdmaWx0ZXJfZGF0YS5oNT9kb3dubG9hZD0xJywgbWF4PTEzMzEyNDczNCksIEhUTUwodmFsdWU9dScnKSnigKY=

# %%
wsynphot.FilterCurve.load_filter()

# %%
filter = wsynphot.FilterCurve.load_filter('Keck/NIRC2/Kp')

# %%
# %pylab notebook

filter.plot(gca())
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <img src="data:image/png;base64,...">

# %%
filter.zp_vega_f_lambda
# Out:
# <Quantity 4.602862428284952e-11 erg / (Angstrom cm2 s)>

# %%
filter.convert_vega_magnitude_to_f_lambda(0)
# Out:
# <Quantity 4.602862428284952e-11 erg / (Angstrom cm2 s)>

# %%
filter.convert_vega_magnitude_to_f_lambda(14.5)
# Out:
# <Quantity 7.295045328423839e-17 erg / (Angstrom cm2 s)>
